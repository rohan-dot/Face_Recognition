# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               


face_cascade = cv2.CascadeClassifier(r'C:\Users\dell15\opencv\opencv-master\data\haarcascades\haarcascade_profileface.xml')  
#face_cascade_1 = cv2.CascadeClassifier(r'C:\Users\dell15\opencv\opencv-master\data\haarcascades\haarcascade_frontalface_alt.xml')

#face_cascade_1 = cv2.CascadeClassifier(r'C:\Users\dell15\opencv\opencv-master\data\haarcascades\haarcascade_frontalface_alt.xml')

# %%
img = cv2.imread('testing.jpeg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


faces = face_cascade.detectMultiScale(gray)
faces_1 = face_cascade_1.detectMultiScale(gray)


print('Number of faces detected:', len(faces))


for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    

cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1
